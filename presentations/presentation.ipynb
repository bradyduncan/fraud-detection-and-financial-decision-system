# %% [markdown]
# # Fraud Detection XGBoost Demo
#
# This notebook loads precomputed train/validation splits and runs the XGBoost model.

# %%
from pathlib import Path
import sys

def find_repo_root(start: Path) -> Path:
    for p in [start] + list(start.parents):
        if (p / 'src').exists():
            return p
    return start

repo_root = find_repo_root(Path.cwd())
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

print(f'Repo root: {repo_root}')

# %%
from src.utils.data_splits import load_splits

X_train, y_train, X_val, y_val = load_splits()
X_train.shape, X_val.shape, y_train.value_counts()

# %%
from src.fraud_detection_models.xgboost_model import train_and_evaluate

model, train_metrics, val_metrics = train_and_evaluate(
    X_train, y_train, X_val, y_val, threshold=0.5
)
train_metrics, val_metrics
